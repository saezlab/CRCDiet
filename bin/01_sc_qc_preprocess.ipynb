# %% [markdown]
# # Quality Control and Filtering
# In this notebook, we showed the results after QC and preprocessing. The dashed lines represents the threshold that we used for filtering:
# - Percentage of mitocondrial genes < 10
# - Percentage of ribosomal genes > 5
# - Doublet threshold < 20
# - total count < 99 percentile
# - filter out Malat1, Gm42418
# - filter out all mitochondrial and ribosomal genes
#
#
# The script generates at table after filtering each sample which shows number of cells/genes before and after filtering
#
# #### Questions:
# 1. We use different mithocondrial percentage threshold between 10 and 20 in different projects. Should we consider increasing the threshold from 10% to 20% as we lose majority of the cells for some
# samples (e.g. HFD-AOM-DSS-Epi_plus_DN)?
# 2. We observed some extreme cases such as **lgkc, lglc1 and lgha** %total counts plots. Are these ones expected to be so high or is this some technical issue?

# %%
import sc_qc_preprocess

# %%
sc_qc_preprocess.create_filtered_adata_files()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ahmet/Google Drive/Projects/saezlab/CRCDiet/bin/01_sc_qc_preprocess.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/01_sc_qc_preprocess.ipynb#ch0000002?line=0'>1</a> sc_qc_preprocess.create_filtered_adata_files()
#       <a href='vscode-notebook-cell:/Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/01_sc_qc_preprocess.ipynb#ch0000002?line=1'>2</a> print("test")
#
# File ~/Google Drive/Projects/saezlab/CRCDiet/bin/sc_qc_preprocess.py:168, in create_filtered_adata_files()
#     <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/sc_qc_preprocess.py?line=165'>166</a> sample_id = row["sample_id"]
#     <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/sc_qc_preprocess.py?line=166'>167</a> condition = row["condition"]
# --> <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/sc_qc_preprocess.py?line=167'>168</a> adata = utils.read_raw_sc_sample(sample_id)
#     <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/sc_qc_preprocess.py?line=168'>169</a> printmd(f"<h4 style='color:black' align='center'>=============== Processing {condition} ===============")
#     <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/sc_qc_preprocess.py?line=169'>170</a> print(f"")
#
# File ~/Google Drive/Projects/saezlab/CRCDiet/bin/utils.py:70, in read_raw_sc_sample(sample_name)
#      <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/utils.py?line=66'>67</a> def read_raw_sc_sample(sample_name):
#      <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/utils.py?line=67'>68</a>     '''Read raw single-cell data'''
# ---> <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/utils.py?line=69'>70</a>     adata = sc.read_10x_mtx(os.path.join(SC_RAW_DATA_PATH, sample_name, "outs", 'filtered_feature_bc_matrix'), cache=True)
#      <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/utils.py?line=70'>71</a>     adata.var_names_make_unique()
#      <a href='file:///Users/ahmet/Google%20Drive/Projects/saezlab/CRCDiet/bin/utils.py?line=71'>72</a>     return adata
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py:490, in read_10x_mtx(path, var_names, make_unique, cache, cache_compression, gex_only, prefix)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=487'>488</a> genefile_exists = (path / f'{prefix}genes.tsv').is_file()
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=488'>489</a> read = _read_legacy_10x_mtx if genefile_exists else _read_v3_10x_mtx
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=489'>490</a> adata = read(
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=490'>491</a>     str(path),
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=491'>492</a>     var_names=var_names,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=492'>493</a>     make_unique=make_unique,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=493'>494</a>     cache=cache,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=494'>495</a>     cache_compression=cache_compression,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=495'>496</a>     prefix=prefix,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=496'>497</a> )
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=497'>498</a> if genefile_exists or not gex_only:
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=498'>499</a>     return adata
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py:554, in _read_v3_10x_mtx(path, var_names, make_unique, cache, cache_compression, prefix)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=549'>550</a> """
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=550'>551</a> Read mtx from output from Cell Ranger v3 or later versions
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=551'>552</a> """
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=552'>553</a> path = Path(path)
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=553'>554</a> adata = read(
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=554'>555</a>     path / f'{prefix}matrix.mtx.gz',
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=555'>556</a>     cache=cache,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=556'>557</a>     cache_compression=cache_compression,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=557'>558</a> ).T  # transpose the data
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=558'>559</a> genes = pd.read_csv(path / f'{prefix}features.tsv.gz', header=None, sep='\t')
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=559'>560</a> if var_names == 'gene_symbols':
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py:112, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=109'>110</a> filename = Path(filename)  # allow passing strings
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=110'>111</a> if is_valid_filename(filename):
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=111'>112</a>     return _read(
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=112'>113</a>         filename,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=113'>114</a>         backed=backed,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=114'>115</a>         sheet=sheet,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=115'>116</a>         ext=ext,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=116'>117</a>         delimiter=delimiter,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=117'>118</a>         first_column_names=first_column_names,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=118'>119</a>         backup_url=backup_url,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=119'>120</a>         cache=cache,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=120'>121</a>         cache_compression=cache_compression,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=121'>122</a>         **kwargs,
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=122'>123</a>     )
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=123'>124</a> # generate filename and read to dict
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=124'>125</a> filekey = str(filename)
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py:751, in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=748'>749</a>         adata = read_excel(filename, sheet)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=749'>750</a> elif ext in {'mtx', 'mtx.gz'}:
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=750'>751</a>     adata = read_mtx(filename)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=751'>752</a> elif ext == 'csv':
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scanpy/readwrite.py?line=752'>753</a>     adata = read_csv(filename, first_column_names=first_column_names)
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/anndata/_io/read.py:317, in read_mtx(filename, dtype)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/anndata/_io/read.py?line=313'>314</a> from scipy.io import mmread
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/anndata/_io/read.py?line=315'>316</a> # could be rewritten accounting for dtype to be more performant
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/anndata/_io/read.py?line=316'>317</a> X = mmread(fspath(filename)).astype(dtype)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/anndata/_io/read.py?line=317'>318</a> from scipy.sparse import csr_matrix
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/anndata/_io/read.py?line=319'>320</a> X = csr_matrix(X)
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py:76, in mmread(source)
#      <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=59'>60</a> def mmread(source):
#      <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=60'>61</a>     """
#      <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=61'>62</a>     Reads the contents of a Matrix Market file-like 'source' into a matrix.
#      <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=62'>63</a>
#    (...)
#      <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=73'>74</a>         Matrix Market file.
#      <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=74'>75</a>     """
# ---> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=75'>76</a>     return MMFile().read(source)
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py:436, in MMFile.read(self, source)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=433'>434</a> try:
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=434'>435</a>     self._parse_header(stream)
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=435'>436</a>     return self._parse_body(stream)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=437'>438</a> finally:
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=438'>439</a>     if close_it:
#
# File ~/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py:629, in MMFile._parse_body(self, stream)
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=625'>626</a> entry_number = 0
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=626'>627</a> for line in stream:
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=627'>628</a>     # line.startswith('%')
# --> <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=628'>629</a>     if not line or line[0] in ['%', 37] or not line.strip():
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=629'>630</a>         continue
#     <a href='file:///Users/ahmet/opt/anaconda3/envs/crcdiet/lib/python3.9/site-packages/scipy/io/_mmio.py?line=631'>632</a>     if entry_number+1 > entries:
#
# KeyboardInterrupt:

# %%
# !pip freeze
# Out:
# aiohttp==3.8.1
# aiosignal==1.2.0
# alabaster==0.7.12
# aniso8601==9.0.1
# anndata==0.8.0
# annoy==1.17.0
# appdirs==1.4.4
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1649077682618/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1640817743617/work
# argon2-cffi-bindings @ file:///Users/runner/miniforge3/conda-bld/argon2-cffi-bindings_1649500366121/work
# asciitree==0.3.3
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1618968359944/work
# async-timeout==4.0.2
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1640799537051/work
# Babel==2.10.1
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1618230623929/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1649463573192/work
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1649361991009/work
# boto3==1.22.7
# botocore==1.25.7
# Brotli==1.0.9
# cachey==0.2.1
# cellxgene==1.0.1
# certifi==2021.10.8
# cffi @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/croot-2p6q7e2r/cffi_1642701115063/work
# charset-normalizer==2.0.12
# click==8.1.2
# cloudpickle==2.0.0
# cycler==0.11.0
# Cython==0.29.28
# dask==2022.4.1
# dask-image==2021.12.0
# debugpy==1.6.0
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# decoupler==1.1.0
# defusedxml @ file:///home/conda/feedstock_root/build_artifacts/defusedxml_1615232257335/work
# docrep==0.3.2
# docstring-parser==0.14.1
# docutils==0.17.1
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1643888246732/work
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1646044401614/work
# fasteners==0.17.3
# fastjsonschema @ file:///home/conda/feedstock_root/build_artifacts/python-fastjsonschema_1641751198313/work/dist
# Flask==2.1.2
# Flask-Compress==1.12
# Flask-Cors==3.0.10
# Flask-RESTful==0.3.9
# flask-server-timing==0.1.2
# flask-talisman==1.0.0
# flatbuffers==1.12
# flatten-dict==0.4.2
# flit_core @ file:///home/conda/feedstock_root/build_artifacts/flit-core_1645629044586/work/source/flit_core
# fonttools==4.33.3
# freetype-py==2.3.0
# frozenlist==1.3.0
# fsspec==2022.3.0
# gunicorn==20.1.0
# h5py==3.6.0
# harmonypy==0.0.5
# HeapDict==1.0.1
# hsluv==5.0.2
# idna==3.3
# igraph==0.9.10
# imageio==2.18.0
# imagesize==1.3.0
# importlib-metadata @ file:///Users/runner/miniforge3/conda-bld/importlib-metadata_1648728334687/work
# importlib-resources @ file:///home/conda/feedstock_root/build_artifacts/importlib_resources_1650169872758/work
# inflect==5.5.2
# ipykernel==6.13.0
# ipython @ file:///Users/runner/miniforge3/conda-bld/ipython_1648413602796/work
# ipython-genutils==0.2.0
# ipywidgets==7.7.0
# itsdangerous==2.1.2
# jedi @ file:///Users/runner/miniforge3/conda-bld/jedi_1649067175439/work
# Jinja2==3.0.3
# jmespath==1.0.0
# joblib==1.1.0
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema-meta_1642000296051/work
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1650972844302/work
# jupyter-core==4.10.0
# jupyterlab-pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1649936611996/work
# jupyterlab-widgets==1.1.0
# kiwisolver==1.4.2
# leidenalg==0.8.10
# llvmlite==0.38.0
# locket==1.0.0
# magicgui==0.4.0
# MarkupSafe @ file:///Users/runner/miniforge3/conda-bld/markupsafe_1648737704633/work
# matplotlib==3.5.1
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1631080358261/work
# matplotlib-scalebar==0.8.1
# mistune @ file:///Users/runner/miniforge3/conda-bld/mistune_1635844789148/work
# multidict==6.0.2
# napari==0.4.15
# napari-console==0.0.4
# napari-plugin-engine==0.2.0
# napari-svg==0.1.6
# natsort==8.1.0
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1649785910383/work
# nbconvert @ file:///home/conda/feedstock_root/build_artifacts/nbconvert-meta_1649676641343/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1649105480291/work
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1648959695634/work
# networkx==2.8
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1650363291341/work
# npe2==0.3.0
# numba==0.55.1
# numcodecs==0.9.1
# numpy==1.21.6
# numpydoc==1.2.1
# omnipath==1.0.5
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1637239678211/work
# pandas==1.4.2
# pandocfilters @ file:///home/conda/feedstock_root/build_artifacts/pandocfilters_1631603243851/work
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1638334955874/work
# partd==1.2.0
# patsy==0.5.2
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1602535608087/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow==9.1.0
# PIMS==0.5
# Pint==0.19.2
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1649447152425/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1649130487073/work
# psutil==5.9.0
# psygnal==0.3.3
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pure-eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1642875951954/work
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1636257122734/work
# pydantic==1.9.0
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1650904496387/work
# pynndescent==0.5.6
# PyOpenGL==3.1.6
# pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1649603503565/work
# PyQt5==5.15.6
# PyQt5-Qt5==5.15.2
# PyQt5-sip==12.10.1
# pyrsistent @ file:///Users/runner/miniforge3/conda-bld/pyrsistent_1649013453068/work
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
# pytomlpp==1.0.11
# pytz==2022.1
# PyWavelets==1.3.0
# PyYAML==6.0
# pyzmq @ file:///Users/runner/miniforge3/conda-bld/pyzmq_1635877545254/work
# qtconsole==5.3.0
# QtPy==2.0.1
# requests==2.27.1
# s3fs==0.4.2
# s3transfer==0.5.2
# scanpy==1.9.1
# scikit-image==0.19.2
# scikit-learn==1.0.2
# scipy==1.8.0
# scrublet==0.2.3
# seaborn==0.11.2
# Send2Trash @ file:///home/conda/feedstock_root/build_artifacts/send2trash_1628511208346/work
# session-info==1.0.0
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# slicerator==1.1.0
# snowballstemmer==2.2.0
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1638550740809/work
# Sphinx==4.5.0
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.0
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# squidpy==1.2.0
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1644872665635/work
# statsmodels==0.13.2
# stdlib-list==0.8.0
# superqt==0.3.1
# tabulate==0.8.9
# terminado @ file:///Users/runner/miniforge3/conda-bld/terminado_1649103848388/work
# texttable==1.6.4
# threadpoolctl==3.1.0
# tifffile==2022.4.26
# tinycss2 @ file:///home/conda/feedstock_root/build_artifacts/tinycss2_1637612658783/work
# toolz==0.11.2
# tornado @ file:///Users/runner/miniforge3/conda-bld/tornado_1648827305366/work
# tqdm==4.64.0
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1635260543454/work
# typer==0.4.1
# typing_extensions==4.2.0
# umap-learn==0.5.3
# urllib3==1.26.9
# validators==0.18.2
# vispy==0.10.0
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webencodings==0.5.1
# Werkzeug==2.1.2
# widgetsnbextension==3.6.0
# wrapt==1.14.0
# xarray==2022.3.0
# yarl==1.7.2
# zarr==2.11.3
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1649012893348/work
