# %% [markdown]
# # Clustering
#
# This script finds the optimal clustering hyperparameter based on the silhoutte scores. The resulting parameter is saved in the integrated AnnData under ```.uns["leiden_best_silh_param"]```
#
# Warning: This takes a lot of time, do not run this unless necessary. If this is already executed please comtinue with the next step.

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Loading precomputed distance matrix...
# Computing neighbourhood graph...
# Creating clusters with Leiden resolution param: 0.10 ...
# Clustering param: 0.10	Silhoutte score: 0.273
#
#
# Creating clusters with Leiden resolution param: 0.15 ...
# Clustering param: 0.15	Silhoutte score: 0.254
#
# Creating clusters with Leiden resolution param: 0.20 ...
# Clustering param: 0.20	Silhoutte score: 0.257
#
# Creating clusters with Leiden resolution param: 0.25 ...
# Clustering param: 0.25	Silhoutte score: 0.286
#
# Creating clusters with Leiden resolution param: 0.30 ...
# Clustering param: 0.30	Silhoutte score: 0.288
#
# Creating clusters with Leiden resolution param: 0.35 ...
# Clustering param: 0.35	Silhoutte score: 0.250
#
# Creating clusters with Leiden resolution param: 0.40 ...
# Clustering param: 0.40	Silhoutte score: 0.263
#
# Creating clusters with Leiden resolution param: 0.45 ...
# Clustering param: 0.45	Silhoutte score: 0.258
#
# Creating clusters with Leiden resolution param: 0.50 ...
# Clustering param: 0.50	Silhoutte score: 0.239
# .
# .
# .

# %%
# %run cluster.py -i ../data/out_data/sc_integrated.h5ad -o ../data/out_data
# Out:
# Loading precomputed distance matrix...
# Computing neighbourhood graph...
# Creating clusters with Leiden resolution param: 0.30
# Clustering param: 0.30	Silhoutte score: 0.288
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 20, categories length: 29. Some categories will have the same color.
# WARNING: saving figure to file /Users/ahmet/Google Drive/Projects/saezlab/CRCDiet/bin/../plots/cluster/umapres-0.30_silh-0.288_clusters.pdf

# %%
# !pip freeze
# Out:
# aiohttp==3.8.1
# aiosignal==1.2.0
# alabaster==0.7.12
# aniso8601==9.0.1
# anndata==0.8.0
# annoy==1.17.0
# appdirs==1.4.4
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1649077682618/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1640817743617/work
# argon2-cffi-bindings @ file:///Users/runner/miniforge3/conda-bld/argon2-cffi-bindings_1649500366121/work
# asciitree==0.3.3
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1618968359944/work
# async-timeout==4.0.2
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1640799537051/work
# Babel==2.10.1
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1618230623929/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1649463573192/work
# ...
