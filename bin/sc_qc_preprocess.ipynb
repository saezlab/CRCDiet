# %%
import sc_qc_preprocess

# %%
sc_qc_preprocess.create_filtered_adata_files()
# Out:
# <h1 style='color:grey'>=============== Processing ext_L24854_CD-AOM-DSS-Epi_plus_DN-single-cell ===============</span>
# Calculating QC metrics...
# ╒════════════════════════╤══════════════════╤══════════════╤══════════════╕
# │ Sample ID              │ Stage            │   # of cells │   # of genes │
# ╞════════════════════════╪══════════════════╪══════════════╪══════════════╡
# │ CD-AOM-DSS-Epi_plus_DN │ Before filtering │        19617 │        32285 │
# ├────────────────────────┼──────────────────┼──────────────┼──────────────┤
# │ CD-AOM-DSS-Epi_plus_DN │ After filtering  │         7818 │        21618 │
# ╘════════════════════════╧══════════════════╧══════════════╧══════════════╛
# Recalculating QC metrics...
# <h1 style='color:grey'>=============== Processing ext_L24854_CD-AOM-DSS-Immune-single-cell ===============</span>
# Calculating QC metrics...
# ╒═══════════════════╤══════════════════╤══════════════╤══════════════╕
# ...
